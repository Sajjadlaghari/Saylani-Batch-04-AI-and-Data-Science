# %% [markdown]
# # Regular Expression
#
# `+` means minimum 1 <br>
# `*` means 0 to many<br>
#  `ai[0123456789]+` means ai and 1 to many<br>
#   `ai[0123456789]*` means ai and 0 to many<br>
#     `ai[0123456789]{1,5}` means minimum 1 and maximum 5<br>

# %%
import re

# %%
text = """Pakistan Zinda Abad
i'm living in karachi
hello world aaaaaaaUiHHHHHHH
Saylani Mass IT Training
abcd      a
i

"""

print(re.findall('a.i',text))
print(re.findall('a.n',text))
print(re.findall('a.+',text))
print(re.findall('a.{3}n',text))
print(re.findall('a.{1,5}n',text))
print(re.findall('a.*',text))
# Out:
# ['aki', 'aUi', 'ani']
# ['ain']
# ['akistan Zinda Abad', 'arachi', 'aaaaaaaUiHHHHHHH', 'aylani Mass IT Training', 'abcd      a']
# ['aylan', 'ainin']
# ['akistan', 'aylan', 'ainin']
# ['akistan Zinda Abad', 'arachi', 'aaaaaaaUiHHHHHHH', 'aylani Mass IT Training', 'abcd      a']

# %%
rollNo = """

ai37464
ai4654
ai354235
ai37463

"""


print(re.findall('ai[123456789]+',rollNo))
print(re.findall('ai[123456789]{1,5}',rollNo))
print(re.findall('ai[123456789]*',rollNo))
# Out:
# ['ai37464', 'ai4654', 'ai354235', 'ai37463']
# ['ai37464', 'ai4654', 'ai35423', 'ai37463']
# ['ai37464', 'ai4654', 'ai354235', 'ai37463']

# %%
text = """ 

abc
acd
fjf
shdue
dhd
cds
cbx
ss
aaa
abc
bbaabd


"""

print(re.findall('[abc]{1,5}',text))
print(re.findall('[abc]{3,5}',text))
print(re.findall('[abc]{4,5}',text))
# Out:
# ['abc', 'ac', 'c', 'cb', 'aaa', 'abc', 'bbaab']
# ['abc', 'aaa', 'abc', 'bbaab']
# ['bbaab']

# %%
import re

# %%
rawdata = """
05:40 From Ali Asar To Everyone : Saylani-187258
12:05:41 From Hasnain Munir To Everyone : Saylani-187272
12:05:44 From Shaheer Baig To Everyone : Saylani-169519
12:05:45 From Humera Naz To Everyone : Saylani-173431
12:05:47 From Sadia Anwar To Everyone : Saylani-180028
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?
12:06:28 From Gulshan Ali To Everyone : Saylani-176719
12:06:29 From M Ali Asif Khan - Saylani-57947 To Everyone : Saylani-57947
12:06:33 From Usman Noor Saylani-188401 To Everyone : Saylani-188401
12:06:46 From Zia (Saylani121514) To Everyone : thanks
12:06:49 From Sohaib Baseer Ahmad To Everyone : Saylani67260
12:40:20 From Ali Asar To Everyone : Saylani-187258
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

"""
# pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"
# pattern = r"(\d{2}:\d{2}:\d{2})"

pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,})"

final = re.findall(pattern,rawdata)

for ri,r in enumerate(final):
    print(r)

# l = re.findall(pattern, rawdata)
# for rid,r in enumerate(l):
#     print(rid, r)
# Out:
# ('12:05:41', 'Hasnain Munir', 'Saylani-187272')
# ('12:05:44', 'Shaheer Baig', 'Saylani-169519')
# ('12:05:45', 'Humera Naz', 'Saylani-173431')
# ('12:05:47', 'Sadia Anwar', 'Saylani-180028')
# ('12:05:47', 'Muhammad Mehroz', 'Saylani-131496')
# ('12:05:47', 'Home', 'Saylani-172998')
# ('12:05:47', 'Muhammad Sadullah = Saylani-178950', 'Saylani-178950')
# ('12:05:48', 'Muhammad Uzair-177637', 'Saylani-177637')
# ('12:05:48', 'Taqwa Khaliq', 'Saylani-173701')
# ('12:05:48', 'asghar ibraheem Saylani-012105', 'Saylani-012105')
# ('12:05:49', 'Faisal Bashir-177802', 'Saylani-177802')
# ('12:05:50', 'Talha Munir Rana', 'Saylani-173761')
# ('12:05:52', 'Abdul Qadar', 'Saylani-172941')
# ('12:05:57', 'Dr. Bhagwan Das', 'Saylani-96879')
# ('12:05:57', 'Uzair Ullah (Saylani169405)', 'Saylani-169405')
# ('12:06:00', 'Arshad', 'Saylani168092')
# ('12:06:01', 'Saylani188523 Subhan Ahmed', 'Saylani188523')
# ('12:06:10', 'Ali Asar', 'Saylani-188720')
# ...

# %%
import pandas as pd

df = pd.DataFrame(final, columns=["Timing",'Name',"Roll number"])
df
# Out:
#       Timing                                Name     Roll number
# 0   12:05:41                       Hasnain Munir  Saylani-187272
# 1   12:05:44                        Shaheer Baig  Saylani-169519
# 2   12:05:45                          Humera Naz  Saylani-173431
# 3   12:05:47                         Sadia Anwar  Saylani-180028
# 4   12:05:47                     Muhammad Mehroz  Saylani-131496
# 5   12:05:47                                Home  Saylani-172998
# 6   12:05:47  Muhammad Sadullah = Saylani-178950  Saylani-178950
# 7   12:05:48               Muhammad Uzair-177637  Saylani-177637
# 8   12:05:48                        Taqwa Khaliq  Saylani-173701
# 9   12:05:48      asghar ibraheem Saylani-012105  Saylani-012105
# 10  12:05:49                Faisal Bashir-177802  Saylani-177802
# 11  12:05:50                    Talha Munir Rana  Saylani-173761
# 12  12:05:52                         Abdul Qadar  Saylani-172941
# ...

# %%
rawdata = """
05:40 From Ali Asar To Everyone : Saylani-187258
12:05:41 From Hasnain Munir To Everyone : Saylani-187272
12:05:44 From Shaheer Baig To Everyone : Saylani-169519
12:05:45 From Humera Naz To Everyone : Saylani-173431
12:05:47 From Sadia Anwar To Everyone : Saylani-180028
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?
12:06:28 From Gulshan Ali To Everyone : Saylani-176719
12:06:29 From M Ali Asif Khan - Saylani-57947 To Everyone : Saylani-57947
12:06:33 From Usman Noor Saylani-188401 To Everyone : Saylani-188401
12:06:46 From Zia (Saylani121514) To Everyone : thanks
12:06:49 From Sohaib Baseer Ahmad To Everyone : Saylani67260
12:40:20 From Ali Asar To Everyone : Saylani-187258
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

"""


# pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"


pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"
# pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"
final = re.findall(pattern,rawdata)

for studnt,isd in enumerate(final):
    print(isd)
    
import pandas as pd

showtable = pd.DataFrame(final, columns=["Timing",'Name',"Roll number"])

showtable
# Out:
# ('12:05:41', 'Hasnain Munir', 'Saylani-187272')
# ('12:05:44', 'Shaheer Baig', 'Saylani-169519')
# ('12:05:45', 'Humera Naz', 'Saylani-173431')
# ('12:05:47', 'Sadia Anwar', 'Saylani-180028')
# ('12:05:47', 'Muhammad Mehroz', 'Saylani-131496')
# ('12:05:47', 'Home', 'Saylani-172998')
# ('12:05:47', 'Muhammad Sadullah = Saylani-178950', 'Saylani-178950')
# ('12:05:48', 'Muhammad Uzair-177637', 'Saylani-177637')
# ('12:05:48', 'Taqwa Khaliq', 'Saylani-173701')
# ('12:05:48', 'asghar ibraheem Saylani-012105', 'Saylani-012105')
# ('12:05:49', 'Faisal Bashir-177802', 'Saylani-177802')
# ('12:05:50', 'Talha Munir Rana', 'Saylani-173761')
# ('12:05:52', 'Abdul Qadar', 'Saylani-172941')
# ('12:05:57', 'Dr. Bhagwan Das', 'Saylani-96879')
# ('12:05:57', 'Uzair Ullah (Saylani169405)', 'Saylani-169405')
# ('12:06:00', 'Arshad', 'Saylani168092')
# ('12:06:01', 'Saylani188523 Subhan Ahmed', 'Saylani188523')
# ('12:06:10', 'Ali Asar', 'Saylani-188720')
# ...

# %%
rawdata = """
05:40 From Ali Asar To Everyone : Saylani-187258
12:05:41 From Hasnain Munir To Everyone : Saylani-187272
12:05:44 From Shaheer Baig To Everyone : Saylani-169519
12:05:45 From Humera Naz To Everyone : Saylani-173431
12:05:47 From Sadia Anwar To Everyone : Saylani-180028
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?
12:06:28 From Gulshan Ali To Everyone : Saylani-176719
12:06:29 From M Ali Asif Khan - Saylani-57947 To Everyone : Saylani-57947
12:06:33 From Usman Noor Saylani-188401 To Everyone : Saylani-188401
12:06:46 From Zia (Saylani121514) To Everyone : thanks
12:06:49 From Sohaib Baseer Ahmad To Everyone : Saylani67260
12:40:20 From Ali Asar To Everyone : Saylani-187258
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

"""

pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"


final = re.findall(pattern,rawdata)


import pandas as pd

# show = pd.DataFrame(final, column=["Time", "Name","RollNo"])
finalData = pd.DataFrame(final, columns=["Timing",'Name',"Roll number"])

finalData


finalData.to_excel("attendance.xlsx", index=False)

# %%
rawdata = """
05:40 From Ali Asar To Everyone : Saylani-187258
12:05:41 From Hasnain Munir To Everyone : Saylani-187272
12:05:44 From Shaheer Baig To Everyone : Saylani-169519
12:05:45 From Humera Naz To Everyone : Saylani-173431
12:05:47 From Sadia Anwar To Everyone : Saylani-180028
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?
12:06:28 From Gulshan Ali To Everyone : Saylani-176719
12:06:29 From M Ali Asif Khan - Saylani-57947 To Everyone : Saylani-57947
12:06:33 From Usman Noor Saylani-188401 To Everyone : Saylani-188401
12:06:46 From Zia (Saylani121514) To Everyone : thanks
12:06:49 From Sohaib Baseer Ahmad To Everyone : Saylani67260
12:40:20 From Ali Asar To Everyone : Saylani-187258
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

"""

pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"


final = re.findall(pattern,rawdata)

# for id,attn in enumerate(final):
#     print(attn)

import pandas as pd

show=pd.DataFrame(final,columns=["Time", "Name","RollNo"])

show.to_excel("Attendance.xlsx",index=False)

# %%
import re
import pandas as pd

rawdata = """
05:40 From Ali Asar To Everyone : Saylani-187258
12:05:41 From Hasnain Munir To Everyone : Saylani-187272
12:05:44 From Shaheer Baig To Everyone : Saylani-169519
12:05:45 From Humera Naz To Everyone : Saylani-173431
12:05:47 From Sadia Anwar To Everyone : Saylani-180028
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?
12:06:28 From Gulshan Ali To Everyone : Saylani-176719
12:06:29 From M Ali Asif Khan - Saylani-57947 To Everyone : Saylani-57947
12:06:33 From Usman Noor Saylani-188401 To Everyone : Saylani-188401
12:06:46 From Zia (Saylani121514) To Everyone : thanks
12:06:49 From Sohaib Baseer Ahmad To Everyone : Saylani67260
12:40:20 From Ali Asar To Everyone : Saylani-187258
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

"""


pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"

final = re.findall(pattern,rawdata)

showTable = pd.DataFrame(final,columns=["Time","Name","RollNo"])

showTable

showTable.to_excel("Attendance.xlsx",index=False)

# %%
import re
import pandas as pd

rawdata = """
05:40 From Ali Asar To Everyone : Saylani-187258
12:05:41 From Hasnain Munir To Everyone : Saylani-187272
12:05:44 From Shaheer Baig To Everyone : Saylani-169519
12:05:45 From Humera Naz To Everyone : Saylani-173431
12:05:47 From Sadia Anwar To Everyone : Saylani-180028
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?
12:06:28 From Gulshan Ali To Everyone : Saylani-176719
12:06:29 From M Ali Asif Khan - Saylani-57947 To Everyone : Saylani-57947
12:06:33 From Usman Noor Saylani-188401 To Everyone : Saylani-188401
12:06:46 From Zia (Saylani121514) To Everyone : thanks
12:06:49 From Sohaib Baseer Ahmad To Everyone : Saylani67260
12:40:20 From Ali Asar To Everyone : Saylani-187258
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

"""

pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"

final = re.findall(pattern,rawdata)

show = pd.DataFrame(final,columns=["Time", "Name","RollNo"])

show
# Out:
#         Time                                Name          RollNo
# 0   12:05:41                       Hasnain Munir  Saylani-187272
# 1   12:05:44                        Shaheer Baig  Saylani-169519
# 2   12:05:45                          Humera Naz  Saylani-173431
# 3   12:05:47                         Sadia Anwar  Saylani-180028
# 4   12:05:47                     Muhammad Mehroz  Saylani-131496
# 5   12:05:47                                Home  Saylani-172998
# 6   12:05:47  Muhammad Sadullah = Saylani-178950  Saylani-178950
# 7   12:05:48               Muhammad Uzair-177637  Saylani-177637
# 8   12:05:48                        Taqwa Khaliq  Saylani-173701
# 9   12:05:48      asghar ibraheem Saylani-012105  Saylani-012105
# 10  12:05:49                Faisal Bashir-177802  Saylani-177802
# 11  12:05:50                    Talha Munir Rana  Saylani-173761
# 12  12:05:52                         Abdul Qadar  Saylani-172941
# ...

# %%
import re
import pandas as pd


import re
import pandas as pd

rawdata = """
05:40 From Ali Asar To Everyone : Saylani-187258
12:05:41 From Hasnain Munir To Everyone : Saylani-187272
12:05:44 From Shaheer Baig To Everyone : Saylani-169519
12:05:45 From Humera Naz To Everyone : Saylani-173431
12:05:47 From Sadia Anwar To Everyone : Saylani-180028
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?
12:06:28 From Gulshan Ali To Everyone : Saylani-176719
12:06:29 From M Ali Asif Khan - Saylani-57947 To Everyone : Saylani-57947
12:06:33 From Usman Noor Saylani-188401 To Everyone : Saylani-188401
12:06:46 From Zia (Saylani121514) To Everyone : thanks
12:06:49 From Sohaib Baseer Ahmad To Everyone : Saylani67260
12:40:20 From Ali Asar To Everyone : Saylani-187258
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

"""


pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"
# pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"



final = re.findall(pattern,rawdata)
final
# Out:
# [('12:05:41', 'Hasnain Munir', 'Saylani-187272'),
#  ('12:05:44', 'Shaheer Baig', 'Saylani-169519'),
#  ('12:05:45', 'Humera Naz', 'Saylani-173431'),
#  ('12:05:47', 'Sadia Anwar', 'Saylani-180028'),
#  ('12:05:47', 'Muhammad Mehroz', 'Saylani-131496'),
#  ('12:05:47', 'Home', 'Saylani-172998'),
#  ('12:05:47', 'Muhammad Sadullah = Saylani-178950', 'Saylani-178950'),
#  ('12:05:48', 'Muhammad Uzair-177637', 'Saylani-177637'),
#  ('12:05:48', 'Taqwa Khaliq', 'Saylani-173701'),
#  ('12:05:48', 'asghar ibraheem Saylani-012105', 'Saylani-012105'),
#  ('12:05:49', 'Faisal Bashir-177802', 'Saylani-177802'),
#  ('12:05:50', 'Talha Munir Rana', 'Saylani-173761'),
#  ('12:05:52', 'Abdul Qadar', 'Saylani-172941'),
#  ('12:05:57', 'Dr. Bhagwan Das', 'Saylani-96879'),
#  ('12:05:57', 'Uzair Ullah (Saylani169405)', 'Saylani-169405'),
#  ('12:06:00', 'Arshad', 'Saylani168092'),
#  ('12:06:01', 'Saylani188523 Subhan Ahmed', 'Saylani188523'),
#  ('12:06:10', 'Ali Asar', 'Saylani-188720'),
# ...

# %%
import re
import pandas as pd


rawdata = """
05:40 From Ali Asar To Everyone : Saylani-187258
12:05:41 From Hasnain Munir To Everyone : Saylani-187272
12:05:44 From Shaheer Baig To Everyone : Saylani-169519
12:05:45 From Humera Naz To Everyone : Saylani-173431
12:05:47 From Sadia Anwar To Everyone : Saylani-180028
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?
12:06:28 From Gulshan Ali To Everyone : Saylani-176719
12:06:29 From M Ali Asif Khan - Saylani-57947 To Everyone : Saylani-57947
12:06:33 From Usman Noor Saylani-188401 To Everyone : Saylani-188401
12:06:46 From Zia (Saylani121514) To Everyone : thanks
12:06:49 From Sohaib Baseer Ahmad To Everyone : Saylani67260
12:40:20 From Ali Asar To Everyone : Saylani-187258
12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

12:05:47 From Muhammad Mehroz To Everyone : Saylani-131496
12:05:47 From Home To Everyone : Saylani-172998
12:05:47 From Muhammad Sadullah = Saylani-178950 To Everyone : Saylani-178950
12:05:48 From Muhammad Uzair-177637 To Everyone : Saylani-177637
12:05:48 From Taqwa Khaliq To Everyone : Saylani-173701 TAQWA KHALIQ
12:05:48 From asghar ibraheem Saylani-012105 To Everyone : Saylani-012105
12:05:49 From Faisal Bashir-177802 To Everyone : Saylani-177802
12:05:50 From Talha Munir Rana To Everyone : Saylani-173761
12:05:52 From Abdul Qadar To Everyone : Saylani-172941
12:05:57 From Dr. Bhagwan Das To Everyone : Saylani-96879
12:05:57 From Uzair Ullah (Saylani169405) To Everyone : Saylani-169405
12:06:00 From Arshad To Everyone : Saylani168092
12:06:01 From Saylani188523 Subhan Ahmed To Everyone : Saylani188523
12:06:04 From Taqwa Khaliq To Everyone : Saylani 173701
12:06:10 From Ali Asar To Everyone : Saylani-188720
12:06:23 From Mohammad Javed To Everyone : WhatsApp number?

"""


pattern = r"(\d{2}:\d{2}:\d{2}) From (.+) To Everyone : (Saylani-?\d{5,6})"


final = re.findall(pattern,rawdata)

# final


showTable = pd.DataFrame(final,columns=["Time","Name", "RollNo"])

showTable


showTable.to_excel("Attendance.xlsx",index=False)
