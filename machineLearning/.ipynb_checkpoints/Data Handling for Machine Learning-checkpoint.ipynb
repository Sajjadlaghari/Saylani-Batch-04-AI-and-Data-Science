# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image
img = mpimg.imread('image.jpeg')

# Convert image to PIL Image object
pil_img = Image.fromarray(img)

# Resize the image to 150x150 pixels
new_size = (500, 500)
resized_img = pil_img.resize(new_size)

# Convert back to NumPy array for display
resized_np = np.array(resized_img)

# Display the resized image using imshow
plt.imshow(resized_np)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()

# %%
from PIL import Image

img = Image.open('image.jpeg') # load image with operating system image viwer application
arr = np.array(img)


img.show()

# %%
pip install opencv-python
# Out:
# ...
#      -------------------------------------- 38.1/38.1 MB 375.0 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

img = cv2.imread('image.jpeg') # GBR <- RGB
plt.imshow(img)
plt.show()

# %%
import cv2

img = cv2.imread('image.jpeg') # GBR <- RGB
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2

cap = cv2.VideoCapture(0)
 
while(True):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
 
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# !pip install tensorflow
# Out:
# ...
#      ------------------------------------ 276.5/276.5 MB 539.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.6/5.6 MB 568.4 kB/s eta 0:00:00
# ...
#      -------------------------------------- 57.5/57.5 kB 749.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.2/4.2 MB 651.9 kB/s eta 0:00:00
# ...
#      -------------------------------------- 24.4/24.4 MB 515.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 126.5/126.5 kB 930.5 kB/s eta 0:00:00
# ...
#      -------------------------------------- 65.5/65.5 kB 708.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 402.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.7/1.7 MB 265.0 kB/s eta 0:00:00
# ...
#      ------------------------------------ 440.8/440.8 kB 357.9 kB/s eta 0:00:00
# ...
#      ------------------------------------ 181.8/181.8 kB 332.4 kB/s eta 0:00:00
# ...
#      ------------------------------------ 151.7/151.7 kB 301.6 kB/s eta 0:00:00
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

training_datagen = ImageDataGenerator(rescale=1.0/255)#rescale=1.0/255
training_dir = 'training' # folder path


# now loading or generate tensor or numpy array from folder 
train_generator = training_datagen.flow_from_directory(
    training_dir,
    target_size=(150,150),
    batch_size=16,
    class_mode='binary'
)
# Out:
# Found 4 images belonging to 2 classes.

# %%
train_generator[0][0][0]
plt.imshow(train_generator[0][0][0])

plt.show()

# %%
batch_images, batch_labels = next(train_generator)

# Iterate through the batch
for i in range(len(batch_images)):
    # Check if the label indicates a cat (assuming 0 corresponds to cats)
    if batch_labels[i] == 1:
        # Display the cat image
        plt.imshow(batch_images[i])
        plt.title("Dog")
        plt.show()

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

training_datagen = ImageDataGenerator(rescale=1.0/255)#rescale=1.0/255
training_dir = 'C:/Users/Sajjad Sindhi/Desktop/training' # folder path


# now loading or generate tensor or numpy array from folder 
train_generator = training_datagen.flow_from_directory(
    training_dir,
    target_size=(150,150),
    batch_size=16,
    class_mode='binary'
)

batch_images, batch_labels = next(train_generator)

# Iterate through the batch
for i in range(len(batch_images)):
    # Check if the label indicates a cat (assuming 0 corresponds to cats)
    if batch_labels[i] == 1:
        # Display the cat image
        plt.imshow(batch_images[i])
        plt.title("Dog")
        plt.show()
# Out:
# Found 4 images belonging to 2 classes.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# Sample text data
text_data = ["This is an example sentence.", "Another sentence for testing."]

# Create a tokenizer with vocabulary size restriction
tokenizer = Tokenizer(num_words=1000, oov_token="<OOV>")

# Fit the tokenizer on text data
tokenizer.fit_on_texts(text_data)



# Convert text to sequences of integers
text_sequences = tokenizer.texts_to_sequences(text_data)

# Print the word index
print("Word index:", tokenizer.word_index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 18
#      15 text_sequences = tokenizer.texts_to_sequences(text_data)
#      17 # Print the word index
# ---> 18 print("Word index:", tokenizer.text_sequences)
#
# AttributeError: 'Tokenizer' object has no attribute 'text_sequences'

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('image.jpeg')

img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)



img = cv2.imread('image.jpeg') # GBR <- RGB
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()



plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 6
#       2 import matplotlib.pyplot as plt
#       4 img = cv2.imread('image.jpeg')
# ----> 6 img = img.cvtColor(img,cv2.COLOR_GBR2RGB)
#      11 plt.imshow(img)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'cvtColor'
